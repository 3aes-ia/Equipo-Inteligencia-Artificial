# %% [markdown]
# <a href="https://colab.research.google.com/github/3aes-ia/Equipo-Inteligencia-Artificial/blob/main/IA_y_Red_Neu_A5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Actividad 5: Procesamiento de conjuntos de datos en Python

# %% [markdown]
# # Inteligencia Artificial
# - Eladio Juvera González 2114783
# - Antonio Contreras Luevanos 2115255
# - Carlos Alberto Aldana Sandoval 2114989
# - Sofía Alejandra Martínez Gómez 1998005
# - Héctor Alexander Salazar Martínez 2177985

# %%
#librerías
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 1) Cargar el dataset con pandas

# %%
# Cargar datos desde un archivo CSV
df = pd.read_csv('/content/robot_sensors.csv')

# %% [markdown]
# 2. Mostrar primeras filas del dataset

# %%
# Muestra las primeras 10 líneas de datos.
print(df.head(10))
# Out:
#    Tiempo (s)  Distancia (cm)  Velocidad (cm/s)  Temperatura (°C)
# 0           0       43.708611          9.256646         23.925585
# 1           1       95.564288         27.095047         23.704682
# 2           2       75.879455         43.647292         33.593819
# 3           3       63.879264         36.611244         23.743193
# 4           4       24.041678         40.328057         24.079246
# 5           5       24.039507         32.939168         31.390974
# 6           6       15.227525         34.613828         26.746098
# 7           7       87.955853         42.459783         31.650658
# 8           8       64.100351         12.483400         20.980492
# 9           9       73.726532         24.471248         27.313568

# %%
# Obtén información sobre las columnas y el tipo de datos de cada una.
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Tiempo (s)        1000 non-null   int64
#  1   Distancia (cm)    970 non-null    float64
#  2   Velocidad (cm/s)  970 non-null    float64
#  3   Temperatura (°C)  970 non-null    float64
# dtypes: float64(3), int64(1)
# memory usage: 31.4 KB
# None

# %%
# Verifica si hay valores nulos
print(df.isnull().sum())
# Out:
# Tiempo (s)           0
# Distancia (cm)      30
# Velocidad (cm/s)    30
# Temperatura (°C)    30
# dtype: int64

# %% [markdown]
# 3. Limpiar los datos

# %% [markdown]
# a. Eliminar filas con valores nulos

# %%
df = df.dropna()

# %%
# Obtén información sobre las columnas y el tipo de datos de cada una.
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 913 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Tiempo (s)        913 non-null    int64
#  1   Distancia (cm)    913 non-null    float64
#  2   Velocidad (cm/s)  913 non-null    float64
#  3   Temperatura (°C)  913 non-null    float64
# dtypes: float64(3), int64(1)
# memory usage: 35.7 KB
# None

# %%
# Verifica si hay valores nulos
print(df.isnull().sum())
# Out:
# Tiempo (s)          0
# Distancia (cm)      0
# Velocidad (cm/s)    0
# Temperatura (°C)    0
# dtype: int64

# %% [markdown]
# b. Filtrar valores atipicos

# %%
df = df[df["Velocidad (cm/s)"] >= 0]
df = df[df["Tiempo (s)"] >= 0]
df = df[df["Distancia (cm)"] >= 0]
df = df[df["Temperatura (°C)"] >= 0]

# %% [markdown]
# 4. Normalizar los datos numéricos con Min-Max Scaling

# %%
columnas = ["Tiempo (s)", "Distancia (cm)", "Velocidad (cm/s)", "Temperatura (°C)"]

for col in columnas:
    df[col] = (df[col] - df[col].min()) / (df[col].max() - df[col].min())

# %%
df.head()
# Out:
#    Tiempo (s)  Distancia (cm)  Velocidad (cm/s)  Temperatura (°C)
# 0    0.000000        0.371735          0.182609          0.262269
# 1    0.001001        0.950755          0.540740          0.247509
# 2    0.002002        0.730954          0.873049          0.908233
# 3    0.003003        0.596960          0.731791          0.250082
# 4    0.004004        0.152134          0.806411          0.272535

# %% [markdown]
# 5. Visualizar los datos normalizados usando matplotlib

# %%
df.plot()
plt.title("Datos Normalizados")
plt.show()
